# %%
import tushare as ts
sh_index = ts.get_hist_data('sh')

# %%
# k线图
import matplotlib.pyplot as plt
import matplotlib.finance as mpf
from matplotlib.pylab import date2num
import datetime

# %matplotlib inline
    
data_list = [(date2num(datetime.datetime.strptime(r.Index,'%Y-%m-%d')), r.open, r.high, r.low, r.close) for r in sh_index.itertuples()]
 
# 创建子图
fig, ax = plt.subplots(figsize=(20, 10))
# 设置X轴刻度为日期时间
ax.xaxis_date()
plt.xticks(rotation=45)
plt.yticks()
plt.title("SH INDEX")
plt.xlabel("TIME")
plt.ylabel("INDEX")
mpf.candlestick_ohlc(ax,data_list,width=1.5,colorup='r',colordown='green')
plt.grid()

# %%
sh_index[-10:]
# Out:
#                 open      high     close       low      volume  price_change  \
# date
# 2015-02-10  3090.490  3142.099  3141.593  3084.253  1938171.38        46.469
# 2015-02-09  3063.510  3119.034  3095.124  3049.111  2061083.88        19.217
# 2015-02-06  3120.090  3129.539  3075.907  3052.939  2467496.75       -60.624
# 2015-02-05  3251.212  3251.212  3136.531  3135.819  3061393.00       -37.595
# 2015-02-04  3212.822  3238.982  3174.126  3171.144  2490980.75       -30.781
# 2015-02-03  3156.086  3207.935  3204.907  3129.732  2481921.75        76.607
# 2015-02-02  3148.136  3175.134  3128.300  3122.572  2508616.25       -82.063
# 2015-01-30  3273.747  3288.503  3210.363  3210.308  2583125.50       -51.942
# 2015-01-29  3258.997  3286.786  3262.305  3234.241  2746586.25       -43.433
# 2015-01-28  3325.722  3354.802  3305.738  3294.655  3019271.00       -47.222
#
#             p_change       ma5      ma10      ma20       v_ma5      v_ma10  \
# date
# 2015-02-10      1.50  3124.656  3173.489  3173.489  2403825.15  2535864.65
# 2015-02-09      0.62  3137.319  3177.033  3177.033  2512575.23  2602275.01
# 2015-02-06     -1.93  3143.954  3187.272  3187.272  2602081.70  2669923.91
# 2015-02-05     -1.18  3170.845  3203.181  3203.181  2625207.45  2698842.07
# 2015-02-04     -0.96  3196.000  3214.290  3214.290  2562246.10  2638416.92
# 2015-02-03      2.45  3222.323  3222.323  3222.323  2667904.15  2667904.15
# 2015-02-02     -2.56  3226.677  3226.677  3226.677  2714399.75  2714399.75
# 2015-01-30     -1.59  3259.469  3259.469  3259.469  2782994.25  2782994.25
# 2015-01-29     -1.31  3284.022  3284.022  3284.022  2882928.63  2882928.63
# 2015-01-28     -1.41  3305.738  3305.738  3305.738  3019271.00  3019271.00
#
#                 v_ma20
# date
# 2015-02-10  2535864.65
# 2015-02-09  2602275.01
# 2015-02-06  2669923.91
# 2015-02-05  2698842.07
# 2015-02-04  2638416.92
# 2015-02-03  2667904.15
# 2015-02-02  2714399.75
# 2015-01-30  2782994.25
# 2015-01-29  2882928.63
# 2015-01-28  3019271.00
